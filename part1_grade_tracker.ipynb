# %%
## Task 1 — Data Parsing & Profile Cleaning (5 marks)
raw_students = [
    {"name": "  ayesha SHARMA  ", "roll": "101", "marks_str": "88, 72, 95, 60, 78"},
    {"name": "ROHIT verma",       "roll": "102", "marks_str": "55, 68, 49, 72, 61"},
    {"name": "  Priya Nair  ",    "roll": "103", "marks_str": "91, 85, 88, 94, 79"},
    {"name": "karan MEHTA",       "roll": "104", "marks_str": "40, 55, 38, 62, 50"},
    {"name": " Sneha pillai ",    "roll": "105", "marks_str": "75, 80, 70, 68, 85"},]


# Step 1: Clean and transform the data
cleaned_students = []
for student in raw_students:
    cleaned = {
        "name": student["name"].strip().title(),
        "roll": int(student["roll"]),
     "marks": [int(m) for m in student["marks_str"].split(", ")]
    }
    cleaned_students.append(cleaned)
    print(f"Cleaned student data: {cleaned}")

# Steps 2 & 3: Validate name + print profile card
for s in cleaned_students:
    is_valid = all(word.isalpha() for word in s["name"].split())
    validity = "✓ Valid name" if is_valid else "✗ Invalid name"

    print("================================")
    print(f"Student : {s['name']}  [{validity}]")
    print(f"Roll No : {s['roll']}")
    print(f"Marks   : {s['marks']}")
    print("================================\n")

# Step 4: ALL CAPS and lowercase for roll 103 
student_103 = next(s for s in cleaned_students if s["roll"] == 103)
print(f"Roll 103 — ALL CAPS  : {student_103['name'].upper()}")
print(f"Roll 103 — lowercase : {student_103['name'].lower()}")

##Task 2 — Marks Analysis Using Loops & Conditionals
student_name = "Ayesha Sharma"
subjects     = ["Math", "Physics", "CS", "English", "Chemistry"]
marks        = [88, 72, 95, 60, 78]

# ── Helper: assign grade from marks ─────────────────────────────────────────
def grade_marks(m):
    if m >= 90:   return "A+"
    elif m >= 80: return "A"
    elif m >= 70: return "B"
    elif m >= 60: return "C"
    else:         return "F"

# ── Part 1: Subject-wise report ──────────────────────────────────────────────
print(f"{'='*40}")
print(f"  Subject Report — {student_name}")
print(f"{'='*40}")
print(f"{'Subject':<12} {'Marks':>6}  {'Grade':>5}")
print(f"{'-'*40}")

for subject, mark in zip(subjects, marks):
    grade = grade_marks(mark)       
    print(f"{subject:<12} {mark:>6}  {grade:>5}")
# Out:
# Cleaned student data: {'name': 'Ayesha Sharma', 'roll': 101, 'marks': [88, 72, 95, 60, 78]}
# Cleaned student data: {'name': 'Rohit Verma', 'roll': 102, 'marks': [55, 68, 49, 72, 61]}
# Cleaned student data: {'name': 'Priya Nair', 'roll': 103, 'marks': [91, 85, 88, 94, 79]}
# Cleaned student data: {'name': 'Karan Mehta', 'roll': 104, 'marks': [40, 55, 38, 62, 50]}
# Cleaned student data: {'name': 'Sneha Pillai', 'roll': 105, 'marks': [75, 80, 70, 68, 85]}
# ...
# Student : Ayesha Sharma  [✓ Valid name]
# Roll No : 101
# Marks   : [88, 72, 95, 60, 78]
# ...
#
# ...
# Student : Rohit Verma  [✓ Valid name]
# Roll No : 102
# Marks   : [55, 68, 49, 72, 61]
# ...
#
# ...
# Student : Priya Nair  [✓ Valid name]
# Roll No : 103
# Marks   : [91, 85, 88, 94, 79]
# ...
#
# ...
# Student : Karan Mehta  [✓ Valid name]
# Roll No : 104
# Marks   : [40, 55, 38, 62, 50]
# ...
#
# ...
# Student : Sneha Pillai  [✓ Valid name]
# Roll No : 105
# Marks   : [75, 80, 70, 68, 85]
# ...
#
# Roll 103 — ALL CAPS  : PRIYA NAIR
# Roll 103 — lowercase : priya nair
# ...

# %%
##Task 2 — Marks Analysis Using Loops & Conditionals
student_name = "Ayesha Sharma"
subjects     = ["Math", "Physics", "CS", "English", "Chemistry"]
marks        = [88, 72, 95, 60, 78]

# ── Part 1: Subject-wise report 
def grade_marks(m):
    if m >= 90:   return "A+"
    elif m >= 80: return "A"
    elif m >= 70: return "B"
    elif m >= 60: return "C"
    else:         return "F"


print(f"{'='*40}")
print(f"  Subject Report — {student_name}")
print(f"{'='*40}")
print(f"{'Subject':<12} {'Marks':>6}  {'Grade':>5}")
print(f"{'-'*40}")

for subject, mark in zip(subjects, marks):
    grade = grade_marks(mark)       
    print(f"{subject:<12} {mark:>6}  {grade:>5}")

##    calculate and print
total        = sum(marks)
average      = round(total / len(marks), 2)
highest_idx  = marks.index(max(marks))
lowest_idx   = marks.index(min(marks))

print(f"Total Marks    : {total}")
print(f"Average Marks  : {average}")
print(f"Highest Subject: {subjects[highest_idx]} ({marks[highest_idx]})")
print(f"Lowest Subject : {subjects[lowest_idx]} ({marks[lowest_idx]})")

# ── Part 3: While loop — marks-entry system 

new_count = 0

while True:
    subject_input = input("Enter subject name : ").strip()

    if subject_input.lower() == "done":
        break

    if not subject_input:
        print("⚠ Warning: Subject name cannot be empty.\n")
        continue

    marks_input = input(f"Enter marks for {subject_input} (0–100): ").strip()

    try:
        new_mark = float(marks_input)
        if not (0 <= new_mark <= 100):
            raise ValueError
        subjects.append(subject_input)
        marks.append(int(new_mark))
        new_count += 1
        print(f"✓ Added: {subject_input} — {int(new_mark)} ({get_grade(int(new_mark))})\n")
    except ValueError:
        print(f"⚠ Warning: '{marks_input}' is invalid. Must be a number between 0–100. Skipped.\n")

# ── Summary ──────────────────────────────────────────────────────────────────
updated_avg = round(sum(marks) / len(marks), 2)
print(f"\nNew subjects added : {new_count}")
print(f"Updated average    : {updated_avg}  (across {len(marks)} subjects)")
# Out:
# ...
#   Subject Report — Ayesha Sharma
# ...
# Subject       Marks  Grade
# ----------------------------------------
# Math             88      A
# Physics          72      B
# CS               95     A+
# English          60      C
# Chemistry        78      B
# Total Marks    : 393
# Average Marks  : 78.6
# Highest Subject: CS (95)
# Lowest Subject : English (60)

# %%
##Task 3 — Class Performance Summary

class_data = [
    ("Ayesha Sharma",  [88, 72, 95, 60, 78]),
    ("Rohit Verma",    [55, 68, 49, 72, 61]),
    ("Priya Nair",     [91, 85, 88, 94, 79]),
    ("Karan Mehta",    [40, 55, 38, 62, 50]),
    ("Sneha Pillai",   [75, 80, 70, 68, 85]),
]

#  Part 1: Compute average and status 
students = []

for name, marks in class_data:
    average = round(sum(marks) / len(marks), 2)
    status  = "Pass" if average >= 60 else "Fail"
    students.append((name, average, status))

# Part 2: Formatted class report 
print(f"{'Name':<18}| {'Average':^7} | {'Status'}")
print("-" * 40)

for name, average, status in students:
    print(f"{name:<18}| {average:^7.2f} | {status}")

#  Part 3: Summary statistics
passed     = [s for s in students if s[2] == "Pass"]
failed     = [s for s in students if s[2] == "Fail"]
topper     = max(students, key=lambda s: s[1])
class_avg  = round(sum(s[1] for s in students) / len(students), 2)

print()
print(f"Passed        : {len(passed)} student(s)")
print(f"Failed        : {len(failed)} student(s)")
print(f"Class Topper  : {topper[0]} ({topper[1]})")
print(f"Class Average : {class_avg}")
# Out:
# Name              | Average | Status
# ----------------------------------------
# Ayesha Sharma     |  78.60  | Pass
# Rohit Verma       |  61.00  | Pass
# Priya Nair        |  87.40  | Pass
# Karan Mehta       |  49.00  | Fail
# Sneha Pillai      |  75.60  | Pass
#
# Passed        : 4 student(s)
# Failed        : 1 student(s)
# Class Topper  : Priya Nair (87.4)
# Class Average : 70.32

# %%
## Task 4 — String Manipulation Utility
essay = "  python is a versatile language. it supports object oriented, functional, and procedural programming. python is widely used in data science and machine learning.  "

# Step 1: Strip whitespace 
clean_essay = essay.strip()
print(f"Step 1 — Cleaned     : {clean_essay}")
print()

#  Step 2: Title Case 
print(f"Step 2 — Title Case  : {clean_essay.title()}")
print()

#  Step 3: Count "python" 
python_count = clean_essay.count("python")
print(f"Step 3 — 'python' count : {python_count}")
print()

#Step 4: Replace "python" with "Python 
replaced = clean_essay.replace("python", "Python ")
print(f"Step 4 — Replaced    : {replaced}")
print()

# Step 5: Split into sentences 
sentences = clean_essay.split(". ")
print(f"Step 5 — Sentences list : {sentences}")
print()

# Step 6: Print numbered sentences 
print("Step 6 — Numbered Sentences:")
for i, sentence in enumerate(sentences, start=1):
    if not sentence.endswith("."):
        sentence += "."
    print(f"  {i}. {sentence}")
# Out:
# Step 1 — Cleaned     : python is a versatile language. it supports object oriented, functional, and procedural programming. python is widely used in data science and machine learning.
#
# Step 2 — Title Case  : Python Is A Versatile Language. It Supports Object Oriented, Functional, And Procedural Programming. Python Is Widely Used In Data Science And Machine Learning.
#
# Step 3 — 'python' count : 2
#
# Step 4 — Replaced    : Python  is a versatile language. it supports object oriented, functional, and procedural programming. Python  is widely used in data science and machine learning.
#
# Step 5 — Sentences list : ['python is a versatile language', 'it supports object oriented, functional, and procedural programming', 'python is widely used in data science and machine learning.']
#
# Step 6 — Numbered Sentences:
#   1. python is a versatile language.
#   2. it supports object oriented, functional, and procedural programming.
# ...
